# %% [markdown]
# # Entrenamiento YOLOv8n con `mikeldiez/kortxovision`
#
# Notebook reproducible en **Google Colab** y también ejecutable en local.
#
# Flujo:
# 1. Carga del dataset
# 2. Conteo de clases
# 3. Muestra de 1 imagen por clase
# 4. Entrenamiento básico (40 épocas)
# 5. Visualización de curvas y matriz de confusión
# 6. Inferencia con una imagen de prueba

# %%
# Fase 0 (setup): instalación de dependencias + imports globales
# Breve: dejamos el entorno listo para entrenar YOLOv8 en Colab/local.

import sys

if 'google.colab' in sys.modules:
    # !pip -q install ultralytics huggingface_hub pyyaml seaborn
else:
    # En local también intentamos instalar por reproducibilidad
    # !pip -q install ultralytics huggingface_hub pyyaml seaborn

# Todos los imports del notebook en una sola celda
from pathlib import Path
from collections import Counter

import cv2
import matplotlib.pyplot as plt
import pandas as pd
import yaml
from huggingface_hub import snapshot_download
from IPython.display import Image, display
from ultralytics import YOLO
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1) Carga del dataset
# Breve: descargamos el dataset desde Hugging Face y detectamos la estructura YOLO.

# %%
DATASET_REPO = 'mikeldiez/kortxovision'
LOCAL_DATA_DIR = Path('./data/kortxovision').resolve()
LOCAL_DATA_DIR.mkdir(parents=True, exist_ok=True)

print(f'Descargando dataset {DATASET_REPO}...')
dataset_root = Path(
    snapshot_download(
        repo_id=DATASET_REPO,
        repo_type='dataset',
        local_dir=str(LOCAL_DATA_DIR),
        local_dir_use_symlinks=False,
    )
).resolve()
print('Dataset descargado en:', dataset_root)

# Detecta YAML de dataset (prioriza data.yml original del repo)
candidate_yaml = (
    list(dataset_root.rglob('data.yml'))
    + list(dataset_root.rglob('data.yaml'))
    + list(dataset_root.rglob('dataset.yml'))
    + list(dataset_root.rglob('dataset.yaml'))
)
if candidate_yaml:
    data_yaml_path = candidate_yaml[0]
    print('Usando YAML existente:', data_yaml_path)
else:
    # Solo si no existe ningún yaml/yml, lo construimos automáticamente
    print('No se encontró data.yml/data.yaml. Generando uno automáticamente...')
    yolo_root = dataset_root

    # Intento de root con carpetas images/labels
    if not (yolo_root / 'images').exists() or not (yolo_root / 'labels').exists():
        # Busca primer nivel que tenga images y labels
        for p in dataset_root.rglob('*'):
            if p.is_dir() and (p / 'images').exists() and (p / 'labels').exists():
                yolo_root = p
                break

    generated_yaml = {
        'path': str(yolo_root),
        'train': 'images/train',
        'val': 'images/validation' if (yolo_root / 'images' / 'validation').exists() else 'images/val',
        'test': 'images/test' if (yolo_root / 'images' / 'test').exists() else 'images/val',
        'names': {},  # lo rellenaremos después con el conteo real de clases
    }

    data_yaml_path = yolo_root / 'data.yaml'
    with open(data_yaml_path, 'w', encoding='utf-8') as f:
        yaml.safe_dump(generated_yaml, f, sort_keys=False, allow_unicode=True)

    print('YAML generado en:', data_yaml_path)

with open(data_yaml_path, 'r', encoding='utf-8') as f:
    data_cfg = yaml.safe_load(f)

print('\nContenido de data.yaml:')
print(data_cfg)
# Out:
# Descargando dataset mikeldiez/kortxovision...
# /home/mikel/github/TKNIKA/kortxovision/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Fetching ... files: 2102it [00:02, 738.35it/s]
# Dataset descargado en: /home/mikel/github/TKNIKA/kortxovision/notebooks/data/kortxovision
# Usando YAML existente: /home/mikel/github/TKNIKA/kortxovision/notebooks/data/kortxovision/data.yml
#
# Contenido de data.yaml:
# {'names': {0: 'destornillador', 1: 'tijeras', 2: 'tenazas', 3: 'llave_inglesa', 4: 'cinta_adhesiva', 5: 'rotulador', 6: 'cutter', 7: 'pinzas', 8: 'lima', 9: 'llave_AlenT', 10: 'llave_dinamometrica', 11: 'calibre', 12: 'nivel', 13: 'polimetro', 14: 'disco_pulido', 15: 'EPIS', 16: 'pelacables'}, 'nc': 17, 'path': '/home/mikel/datasets/kortxovision_mini', 'test': 'images/test', 'train': 'images/train', 'val': 'images/val'}

# %% [markdown]
# ## 2) Conteo de clases
# Breve: recorremos todos los labels y contamos instancias por clase para validar distribución.

# %%
# Resolve root del dataset desde YAML
base_path = Path(data_cfg.get('path', data_yaml_path.parent)).resolve()
labels_root = base_path / 'labels'

if not labels_root.exists():
    # fallback: buscar cualquier carpeta labels
    all_labels = list(base_path.rglob('labels'))
    if not all_labels:
        raise FileNotFoundError(f'No se encontró carpeta labels bajo {base_path}')
    labels_root = all_labels[0]

label_files = list(labels_root.rglob('*.txt'))
print(f'Ficheros de label detectados: {len(label_files)}')

class_counter = Counter()
for lf in label_files:
    with open(lf, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= 5:  # formato YOLO: class x_center y_center w h
                class_id = int(float(parts[0]))
                class_counter[class_id] += 1

if not class_counter:
    raise ValueError('No se encontraron anotaciones válidas en los labels.')

# Resolver nombres de clase (si vienen en YAML, perfecto; si no, genéricos)
if isinstance(data_cfg.get('names'), dict) and data_cfg['names']:
    names_map = {int(k): v for k, v in data_cfg['names'].items()}
elif isinstance(data_cfg.get('names'), list) and data_cfg['names']:
    names_map = {i: n for i, n in enumerate(data_cfg['names'])}
else:
    max_id = max(class_counter.keys())
    names_map = {i: f'class_{i}' for i in range(max_id + 1)}
    data_cfg['names'] = names_map
    with open(data_yaml_path, 'w', encoding='utf-8') as f:
        yaml.safe_dump(data_cfg, f, sort_keys=False, allow_unicode=True)

rows = []
for cid in sorted(class_counter):
    rows.append({
        'class_id': cid,
        'class_name': names_map.get(cid, f'class_{cid}'),
        'instances': class_counter[cid],
    })

class_df = pd.DataFrame(rows)
display(class_df)
print('\nTotal clases:', class_df.shape[0])
print('Total instancias:', int(class_df['instances'].sum()))
# Out:
# Ficheros de label detectados: 960
#     class_id           class_name  instances
# 0          0       destornillador         92
# 1          1              tijeras         83
# 2          2              tenazas        105
# 3          3        llave_inglesa         98
# 4          4       cinta_adhesiva         63
# 5          5            rotulador         71
# 6          6               cutter         47
# 7          7               pinzas         58
# 8          8                 lima         52
# 9          9          llave_AlenT         46
# 10        10  llave_dinamometrica         50
# 11        11              calibre         56
# 12        12                nivel         52
# 13        13            polimetro         55
# 14        14         disco_pulido         53
# 15        15                 EPIS         56
# 16        16           pelacables         52
# Total clases: 17
# Total instancias: 1089

# %% [markdown]
# ## 3) 1 imagen por clase
# Breve: seleccionamos un ejemplo por clase y dibujamos su bounding box para comprobar etiquetado.

# %%
# Localiza carpeta de imágenes de train (fallbacks comunes)
train_images_candidates = [
    base_path / 'images' / 'train',
    base_path / 'train' / 'images',
]
train_images_dir = next((p for p in train_images_candidates if p.exists()), None)
if train_images_dir is None:
    # fallback amplio
    candidates = list(base_path.rglob('images/train')) + list(base_path.rglob('train/images'))
    if not candidates:
        raise FileNotFoundError('No se encontró carpeta de imágenes de train.')
    train_images_dir = candidates[0]

train_labels_candidates = [
    base_path / 'labels' / 'train',
    base_path / 'train' / 'labels',
]
train_labels_dir = next((p for p in train_labels_candidates if p.exists()), None)
if train_labels_dir is None:
    candidates = list(base_path.rglob('labels/train')) + list(base_path.rglob('train/labels'))
    if not candidates:
        raise FileNotFoundError('No se encontró carpeta de labels de train.')
    train_labels_dir = candidates[0]

# Mapea class_id -> (img_path, bbox)
one_sample_per_class = {}

for label_path in sorted(train_labels_dir.rglob('*.txt')):
    stem = label_path.stem
    img_path = None
    for ext in ('.jpg', '.jpeg', '.png', '.webp', '.bmp'):
        candidate = train_images_dir / f'{stem}{ext}'
        if candidate.exists():
            img_path = candidate
            break
    if img_path is None:
        continue

    with open(label_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cid = int(float(parts[0]))
            if cid not in one_sample_per_class:
                x, y, w, h = map(float, parts[1:5])
                one_sample_per_class[cid] = (img_path, (x, y, w, h))

# Plot 1 imagen por clase
class_ids = sorted(one_sample_per_class.keys())
n = len(class_ids)
cols = 4
rows = (n + cols - 1) // cols
plt.figure(figsize=(5 * cols, 4 * rows))

for i, cid in enumerate(class_ids, start=1):
    img_path, (x, y, w, h) = one_sample_per_class[cid]
    img_bgr = cv2.imread(str(img_path))
    img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    ih, iw = img.shape[:2]
    x1 = int((x - w / 2) * iw)
    y1 = int((y - h / 2) * ih)
    x2 = int((x + w / 2) * iw)
    y2 = int((y + h / 2) * ih)

    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    class_name = names_map.get(cid, f'class_{cid}')

    plt.subplot(rows, cols, i)
    plt.imshow(img)
    plt.title(f'{cid}: {class_name}')
    plt.axis('off')

plt.tight_layout()
plt.show()

missing_classes = set(class_counter.keys()) - set(one_sample_per_class.keys())
if missing_classes:
    print('Clases sin muestra visual encontrada:', sorted(missing_classes))

# %% [markdown]
# ## 4) Entrenamiento básico (40 épocas)
# Breve: entrenamos `yolov8n` con parámetros conservadores para una primera baseline reproducible.

# %%
model = YOLO('yolo11m.pt')

train_results = model.train(
    data=str(data_yaml_path),
    epochs=40,
    imgsz=640,
    batch=4,
    project='runs/detect',
    name='yolov11m_kortxovision',
    exist_ok=True,
    pretrained=True,
    seed=42,
    deterministic=True,
)

print('Entrenamiento finalizado. Carpeta de resultados:', train_results.save_dir)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt': 100% ━━━━━━━━━━━━ 38.8MB 21.1MB/s 1.8s1.8s<0.1s
# New https://pypi.org/project/ultralytics/8.4.41 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6141MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/mikel/github/TKNIKA/kortxovision/notebooks/data/kortxovision/data.yml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11m_kortxovision, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=17
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1424131  ultralytics.nn.modules.head.Detect           [17, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,066,115 parameters, 20,066,099 gradients, 68.3 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 317.6±175.5 MB/s, size: 291.0 KB)
# train: Scanning /home/mikel/datasets/kortxovision_mini/labels/train.cache... 672 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 672/672 768.8Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 265.8±161.2 MB/s, size: 278.9 KB)
# val: Scanning /home/mikel/datasets/kortxovision_mini/labels/val.cache... 148 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 148/148 107.4Kit/s 0.0s
# val: /home/mikel/datasets/kortxovision_mini/images/val/destor_tijeras_tenazas_llave_cinta_rotu_blunt_16_jpg.rf.7077490911349c003315194033c0fb75.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3849]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 161. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000476, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      2.32G      1.271      4.192      1.266          5        640: 100% ━━━━━━━━━━━━ 168/168 2.7it/s 1:020.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.9it/s 9.9s0.3s
#                    all        147        161      0.515      0.323      0.344      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      2.77G      1.437      2.703      1.353          3        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.3it/s 3.6s0.2s
#                    all        147        161      0.428      0.451      0.403      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      2.77G       1.52      2.475      1.378          5        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.6it/s 3.4s0.2s
#                    all        147        161       0.62      0.407      0.433      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      2.83G      1.489      2.298      1.408         10        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.511      0.431      0.444       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40       2.9G      1.529      2.308      1.459          9        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.2it/s 3.7s0.2s
#                    all        147        161      0.632      0.482      0.498      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      2.97G      1.483      2.164       1.42          4        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 50.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.3s0.2s
#                    all        147        161      0.537      0.441      0.447      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      2.55G      1.452      1.997      1.388          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.699      0.431      0.511      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      2.84G      1.441      1.835      1.385         10        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.9it/s 3.2s0.2s
#                    all        147        161      0.637      0.493      0.556      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40       2.9G      1.349      1.734      1.363          7        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.552      0.557      0.574      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      2.97G      1.312      1.665      1.363         10        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 51.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.6it/s 3.4s0.2s
#                    all        147        161      0.672      0.561      0.619      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      3.04G      1.329      1.536      1.349          9        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.6it/s 3.4s0.2s
#                    all        147        161      0.667      0.551      0.628      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      2.59G       1.34      1.583      1.344         11        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.9it/s 3.2s0.2s
#                    all        147        161      0.814      0.551      0.629      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      2.65G      1.313       1.51      1.352          7        640: 100% ━━━━━━━━━━━━ 168/168 3.5it/s 48.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.0it/s 3.2s0.2s
#                    all        147        161      0.654      0.555      0.587      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      2.72G      1.268       1.52      1.315          7        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.5it/s 3.5s0.2s
#                    all        147        161      0.756      0.569      0.677      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      2.78G      1.232      1.379      1.259          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.1it/s 3.7s0.2s
#                    all        147        161      0.657      0.658      0.699       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      2.78G      1.194      1.315      1.259          8        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.764      0.602       0.69       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      2.95G       1.22      1.272      1.278         12        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.834      0.647      0.726      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      3.01G      1.176      1.221      1.264          6        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.0it/s 3.2s0.2s
#                    all        147        161      0.854      0.625      0.735       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      2.62G      1.186      1.227      1.257          6        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.4it/s 3.5s0.2s
#                    all        147        161      0.767      0.704      0.772      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      2.66G       1.13      1.193       1.24          5        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.5it/s 3.5s0.2s
#                    all        147        161       0.76      0.709      0.753      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      2.73G      1.099      1.155      1.215          8        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.9it/s 3.2s0.2s
#                    all        147        161      0.838      0.693       0.77      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      2.96G      1.141       1.14      1.245          8        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 49.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.3s0.2s
#                    all        147        161      0.864       0.69      0.781      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      3.02G      1.081      1.021      1.193          9        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.3s0.2s
#                    all        147        161      0.891      0.667      0.773      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      2.63G      1.084     0.9719      1.178          5        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.2it/s 3.6s0.2s
#                    all        147        161      0.737      0.737      0.753      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      2.65G       1.07       1.05      1.204         13        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.2it/s 3.7s0.2s
#                    all        147        161      0.828      0.711      0.786      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      2.66G      1.072      1.021      1.188         10        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.1it/s 3.8s0.2s
#                    all        147        161      0.785      0.751      0.792       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      2.66G      1.052      0.959      1.182          4        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 53.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.3it/s 3.6s0.2s
#                    all        147        161      0.839      0.731      0.796      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      2.72G      1.006     0.9263      1.181          7        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.5it/s 3.5s0.2s
#                    all        147        161      0.761      0.757      0.807      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      2.79G     0.9619     0.8519      1.128         11        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.4s0.2s
#                    all        147        161      0.823      0.737      0.817      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      2.86G     0.9464     0.8339      1.092          7        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.0it/s 3.8s0.2s
#                    all        147        161      0.857      0.703      0.797      0.566
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      2.62G     0.9211     0.8193       1.12          4        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 50.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.862      0.695      0.806      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      2.87G     0.9362      0.752      1.086          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.887      0.752      0.839      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      2.87G     0.9318     0.7082      1.115          5        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.864      0.813      0.864      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      2.94G      0.909     0.7052       1.11          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.6it/s 3.4s0.2s
#                    all        147        161      0.941      0.747      0.868      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40         3G     0.8414     0.6501      1.079          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.3s0.2s
#                    all        147        161       0.87      0.791      0.858      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40       2.6G     0.8524     0.6371      1.078          6        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.4s0.2s
#                    all        147        161      0.871      0.789      0.866      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      2.65G     0.8574     0.6053      1.076          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 51.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.8it/s 3.3s0.2s
#                    all        147        161      0.876      0.787      0.848      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      2.66G     0.8563     0.6161      1.066          4        640: 100% ━━━━━━━━━━━━ 168/168 3.4it/s 50.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.7it/s 3.3s0.2s
#                    all        147        161      0.898      0.779      0.861      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      2.89G     0.8022     0.5822      1.035          4        640: 100% ━━━━━━━━━━━━ 168/168 3.3it/s 50.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.9it/s 3.2s0.2s
#                    all        147        161      0.911      0.782      0.862      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      2.96G     0.8263     0.5867      1.039          4        640: 100% ━━━━━━━━━━━━ 168/168 3.2it/s 52.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.3it/s 3.6s0.2s
#                    all        147        161      0.897      0.775      0.869        0.6
#
# 40 epochs completed in 0.619 hours.
# Optimizer stripped from /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/weights/last.pt, 40.5MB
# Optimizer stripped from /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/weights/best.pt, 40.5MB
#
# Validating /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/weights/best.pt...
# Ultralytics 8.3.203 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6141MiB)
# YOLO11m summary (fused): 125 layers, 20,043,139 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 5.6it/s 3.4s0.2s
#                    all        147        161      0.864      0.812      0.864      0.603
#         destornillador         10         17       0.83      0.588      0.689      0.412
#                tijeras          9          9      0.591      0.644      0.681      0.347
#                tenazas         16         17      0.436      0.882       0.85        0.6
#          llave_inglesa          8         11      0.769      0.727      0.792      0.554
#         cinta_adhesiva          9          9      0.939          1      0.995      0.803
#              rotulador         10         10      0.923        0.8      0.803      0.592
#                 cutter          7          7          1      0.899      0.995      0.641
#                 pinzas          8          8          1      0.726      0.825      0.481
#                   lima         10         10      0.891        0.7      0.756      0.572
#            llave_AlenT          7          7          1      0.962      0.995      0.697
#    llave_dinamometrica          9          9      0.911      0.667      0.769      0.491
#                calibre         11         11      0.904      0.636      0.782      0.627
#                  nivel          7          7          1      0.984      0.995       0.67
#              polimetro          7          7      0.905          1      0.995      0.842
#           disco_pulido          7          7      0.902          1      0.995      0.647
#                   EPIS          7          7      0.803      0.714      0.792      0.494
#             pelacables          8          8      0.889      0.875      0.971      0.782
# Speed: 0.3ms preprocess, 16.2ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision
# Entrenamiento finalizado. Carpeta de resultados: /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision

# %% [markdown]
# ## 5) Curvas de entrenamiento y matriz de confusión
# Breve: revisamos métricas globales del entrenamiento y errores entre clases.

# %%
# Visualización de artefactos generados por Ultralytics
save_dir = Path(train_results.save_dir)

results_png = save_dir / 'results.png'
confusion_png = save_dir / 'confusion_matrix.png'
confusion_norm_png = save_dir / 'confusion_matrix_normalized.png'

if results_png.exists():
    print('Curvas de entrenamiento (loss/mAP):')
    display(Image(filename=str(results_png)))
else:
    print(f'No se encontró {results_png.name} en {save_dir}')

if confusion_png.exists():
    print('Matriz de confusión:')
    display(Image(filename=str(confusion_png)))
elif confusion_norm_png.exists():
    print('Matriz de confusión normalizada:')
    display(Image(filename=str(confusion_norm_png)))
else:
    print('No se encontró matriz de confusión en la carpeta de resultados.')
# Out:
# Curvas de entrenamiento (loss/mAP):
# Matriz de confusión:

# %% [markdown]
# ## 6) Inferencia con una imagen de prueba
# Breve: cargamos el mejor checkpoint y predecimos sobre 1 imagen del split de test.

# %%
# Inferencia configurable sobre imagen fija fuera del dataset (kortxo.jpg)
# 1) modelo base sin fine-tuning
# 2) modelo entrenado en ruta configurable

# ---------------- Configurable ----------------
image_candidates = [
    Path('/home/mikel/github/TKNIKA/kortxovision/test_imgs/test1.jpg').resolve(),
    Path('/home/mikel/github/TKNIKA/kortxovision/test_imgs/test1.jpg').resolve(),
]

BASE_MODEL_ID = 'yolov8n.pt'
TRAINED_WEIGHTS_PATH = Path('/home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/weights/best.pt')
# ----------------------------------------------

test_image = next((p for p in image_candidates if p.exists()), None)
if test_image is None:
    raise FileNotFoundError('No se encontró kortxo.jpg. Colócala en notebooks/kortxo.jpg o en el cwd del notebook.')

trained_weights = TRAINED_WEIGHTS_PATH.resolve()
if not trained_weights.exists():
    raise FileNotFoundError(f'No se encontró el modelo entrenado en: {trained_weights}')

trained_model = YOLO(str(trained_weights))
base_model = YOLO(BASE_MODEL_ID)

# Predicción con modelo base (sin entrenamiento en tu dataset)
pred_base = base_model.predict(
    source=str(test_image),
    conf=0.25,
    save=True,
    project='runs/predict',
    name='kortxo_base',
    exist_ok=True,
)

# Predicción con modelo entrenado
pred_trained = trained_model.predict(
    source=str(test_image),
    conf=0.45,
    iou=0.5,
    agnostic_nms=True,
    max_det=50,
    save=True,
    project='runs/predict',
    name='kortxo_trained',
    exist_ok=True,
)

base_img = Path(pred_base[0].save_dir) / test_image.name
trained_img = Path(pred_trained[0].save_dir) / test_image.name

print('Imagen usada para inferencia:', test_image)
print('Modelo base:', BASE_MODEL_ID)
print('Modelo entrenado:', trained_weights)
print('Salida modelo base:', base_img)
print('Salida modelo entrenado:', trained_img)

if not base_img.exists() or not trained_img.exists():
    raise FileNotFoundError('No se pudieron localizar las imágenes renderizadas de inferencia.')

# Mostrar ambas imágenes lado a lado
img_base = cv2.cvtColor(cv2.imread(str(base_img)), cv2.COLOR_BGR2RGB)
img_trained = cv2.cvtColor(cv2.imread(str(trained_img)), cv2.COLOR_BGR2RGB)

trained_label = f"Entrenado ({trained_weights.parent.parent.name})"

plt.figure(figsize=(16, 7))
plt.subplot(1, 2, 1)
plt.imshow(img_base)
plt.title(f'Base ({BASE_MODEL_ID})')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_trained)
plt.title(trained_label)
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/1 /home/mikel/github/TKNIKA/kortxovision/notebooks/kortxo.jpg: 512x640 1 suitcase, 1 kite, 37.8ms
# Speed: 3.6ms preprocess, 37.8ms inference, 7.6ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/predict/kortxo_base
#
# image 1/1 /home/mikel/github/TKNIKA/kortxovision/notebooks/kortxo.jpg: 512x640 2 destornilladors, 2 tenazass, 30.9ms
# Speed: 1.9ms preprocess, 30.9ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/predict/kortxo_trained
# Imagen usada para inferencia: /home/mikel/github/TKNIKA/kortxovision/notebooks/kortxo.jpg
# Modelo base: yolov8n.pt
# Modelo entrenado: /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/detect/yolov11m_kortxovision/weights/best.pt
# Salida modelo base: /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/predict/kortxo_base/kortxo.jpg
# Salida modelo entrenado: /home/mikel/github/TKNIKA/kortxovision/notebooks/runs/predict/kortxo_trained/kortxo.jpg
